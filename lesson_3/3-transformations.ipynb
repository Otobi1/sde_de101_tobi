# %%
import csv

# %%
# 1: How do you read data from a CSV file into a list of dictionaries?
data = []
with open("./data/sample_data.csv", "r", newline="") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(row)

# %%
data
# Out:
# [{'Customer_ID': '1',
#   'Customer_Name': 'Henry Jones',
#   'Age': '32',
#   'Gender': 'Male',
#   'Purchase_Amount': '1080000.66',
#   'Purchase_Date': '2023-08-15'},
#  {'Customer_ID': '2',
#   'Customer_Name': 'Emma Rodriguez',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '62.4',
#   'Purchase_Date': '2024-04-16'},
#  {'Customer_ID': '3',
#   'Customer_Name': 'Frank Martinez',
#   'Age': '20',
#   'Gender': 'Female',
#   'Purchase_Amount': '443.47',
#   'Purchase_Date': '2024-05-16'},
#  {'Customer_ID': '4',
#   'Customer_Name': 'Alice Rodriguez',
#   'Age': '62',
#   'Gender': 'Female',
#   'Purchase_Amount': '729.69',
#   'Purchase_Date': '2024-01-05'},
#  {'Customer_ID': '5',
#   'Customer_Name': 'Frank Miller',
#   'Age': '33',
#   'Gender': 'Female',
#   'Purchase_Amount': '651.2',
#   'Purchase_Date': '2024-05-23'},
#  {'Customer_ID': '6',
#   'Customer_Name': 'Emma Garcia',
#   'Age': '22',
#   'Gender': 'Female',
#   'Purchase_Amount': '477.56',
#   'Purchase_Date': '2023-09-02'},
#  {'Customer_ID': '7',
#   'Customer_Name': 'Grace Jones',
#   'Age': '53',
#   'Gender': 'Female',
#   'Purchase_Amount': '29.72',
#   'Purchase_Date': '2023-10-01'},
#  {'Customer_ID': '8',
#   'Customer_Name': 'Henry Smith',
#   'Age': '41',
#   'Gender': 'Male',
#   'Purchase_Amount': '291.28',
#   'Purchase_Date': '2024-02-01'},
#  {'Customer_ID': '9',
#   'Customer_Name': 'Emma Jones',
#   'Age': '50',
#   'Gender': 'Female',
#   'Purchase_Amount': '575.69',
#   'Purchase_Date': '2023-12-11'},
#  {'Customer_ID': '10',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '44',
#   'Gender': 'Female',
#   'Purchase_Amount': '30.96',
#   'Purchase_Date': '2024-05-11'},
#  {'Customer_ID': '11',
#   'Customer_Name': 'Grace Miller',
#   'Age': '29',
#   'Gender': 'Male',
#   'Purchase_Amount': '321.42',
#   'Purchase_Date': '2023-10-25'},
#  {'Customer_ID': '12',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '68',
#   'Gender': 'Male',
#   'Purchase_Amount': '470.45',
#   'Purchase_Date': '2023-06-05'},
#  {'Customer_ID': '13',
#   'Customer_Name': 'Charlie Jones',
#   'Age': '24',
#   'Gender': 'Female',
#   'Purchase_Amount': '330.87',
#   'Purchase_Date': '2023-11-11'},
#  {'Customer_ID': '14',
#   'Customer_Name': 'Frank Rodriguez',
#   'Age': '51',
#   'Gender': 'Female',
#   'Purchase_Amount': '483.61',
#   'Purchase_Date': '2024-05-06'},
#  {'Customer_ID': '15',
#   'Customer_Name': 'Alice Jones',
#   'Age': '53',
#   'Gender': 'Male',
#   'Purchase_Amount': '647.13',
#   'Purchase_Date': '2023-12-07'},
#  {'Customer_ID': '16',
#   'Customer_Name': 'Grace Miller',
#   'Age': '36',
#   'Gender': 'Female',
#   'Purchase_Amount': '691.85',
#   'Purchase_Date': '2023-09-25'},
#  {'Customer_ID': '17',
#   'Customer_Name': 'Charlie Miller',
#   'Age': '27',
#   'Gender': 'Male',
#   'Purchase_Amount': '840.67',
#   'Purchase_Date': '2023-07-09'},
#  {'Customer_ID': '18',
#   'Customer_Name': 'Jack Martinez',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '831.8',
#   'Purchase_Date': '2023-11-07'},
#  {'Customer_ID': '19',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '399.76',
#   'Purchase_Date': '2024-02-04'},
#  {'Customer_ID': '20',
#   'Customer_Name': 'Grace Miller',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '917.93',
#   'Purchase_Date': '2023-12-24'},
#  {'Customer_ID': '21',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '21',
#   'Gender': 'Female',
#   'Purchase_Amount': '389.69',
#   'Purchase_Date': '2023-07-19'},
#  {'Customer_ID': '22',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '34',
#   'Gender': 'Male',
#   'Purchase_Amount': '697.0',
#   'Purchase_Date': '2023-07-15'},
#  {'Customer_ID': '23',
#   'Customer_Name': 'Jack Miller',
#   'Age': '55',
#   'Gender': 'Male',
#   'Purchase_Amount': '838.01',
#   'Purchase_Date': '2023-10-22'},
#  {'Customer_ID': '24',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '620.28',
#   'Purchase_Date': '2024-01-19'},
#  {'Customer_ID': '25',
#   'Customer_Name': 'David Johnson',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '964.04',
#   'Purchase_Date': '2023-12-30'},
#  {'Customer_ID': '26',
#   'Customer_Name': 'David Smith',
#   'Age': '36',
#   'Gender': 'Female',
#   'Purchase_Amount': '231.88',
#   'Purchase_Date': '2024-05-27'},
#  {'Customer_ID': '27',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '22',
#   'Gender': 'Female',
#   'Purchase_Amount': '115.68',
#   'Purchase_Date': '2023-08-24'},
#  {'Customer_ID': '28',
#   'Customer_Name': 'Henry Martinez',
#   'Age': '62',
#   'Gender': 'Male',
#   'Purchase_Amount': '735.66',
#   'Purchase_Date': '2023-12-07'},
#  {'Customer_ID': '29',
#   'Customer_Name': 'Charlie Garcia',
#   'Age': '42',
#   'Gender': 'Female',
#   'Purchase_Amount': '696.19',
#   'Purchase_Date': '2023-07-26'},
#  {'Customer_ID': '30',
#   'Customer_Name': 'Grace Davis',
#   'Age': '30',
#   'Gender': 'Female',
#   'Purchase_Amount': '566.13',
#   'Purchase_Date': '2023-07-18'},
#  {'Customer_ID': '31',
#   'Customer_Name': 'Grace Smith',
#   'Age': '19',
#   'Gender': 'Male',
#   'Purchase_Amount': '567.3',
#   'Purchase_Date': '2024-04-13'},
#  {'Customer_ID': '32',
#   'Customer_Name': 'Emma Jones',
#   'Age': '58',
#   'Gender': 'Male',
#   'Purchase_Amount': '299.82',
#   'Purchase_Date': '2024-03-21'},
#  {'Customer_ID': '33',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '43',
#   'Gender': 'Male',
#   'Purchase_Amount': '366.42',
#   'Purchase_Date': '2023-07-30'},
#  {'Customer_ID': '34',
#   'Customer_Name': 'Alice Garcia',
#   'Age': '54',
#   'Gender': 'Male',
#   'Purchase_Amount': '874.08',
#   'Purchase_Date': '2024-04-17'},
#  {'Customer_ID': '35',
#   'Customer_Name': 'Grace Williams',
#   'Age': '58',
#   'Gender': 'Male',
#   'Purchase_Amount': '139.01',
#   'Purchase_Date': '2024-04-23'},
#  {'Customer_ID': '36',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '637.05',
#   'Purchase_Date': '2023-08-06'},
#  {'Customer_ID': '37',
#   'Customer_Name': 'Ivy Miller',
#   'Age': '37',
#   'Gender': 'Male',
#   'Purchase_Amount': '787.06',
#   'Purchase_Date': '2024-05-04'},
#  {'Customer_ID': '38',
#   'Customer_Name': 'Charlie Rodriguez',
#   'Age': '52',
#   'Gender': 'Female',
#   'Purchase_Amount': '853.47',
#   'Purchase_Date': '2023-11-26'},
#  {'Customer_ID': '39',
#   'Customer_Name': 'Grace Garcia',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '901.82',
#   'Purchase_Date': '2023-12-09'},
#  {'Customer_ID': '40',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '61',
#   'Gender': 'Male',
#   'Purchase_Amount': '180.92',
#   'Purchase_Date': '2023-10-02'},
#  {'Customer_ID': '41',
#   'Customer_Name': 'Alice Jones',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '373.03',
#   'Purchase_Date': '2024-03-16'},
#  {'Customer_ID': '42',
#   'Customer_Name': 'Charlie Smith',
#   'Age': '66',
#   'Gender': 'Male',
#   'Purchase_Amount': '392.27',
#   'Purchase_Date': '2023-11-03'},
#  {'Customer_ID': '43',
#   'Customer_Name': 'Bob Williams',
#   'Age': '35',
#   'Gender': 'Female',
#   'Purchase_Amount': '319.58',
#   'Purchase_Date': '2024-03-29'},
#  {'Customer_ID': '44',
#   'Customer_Name': 'Frank Garcia',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '917.63',
#   'Purchase_Date': '2023-07-26'},
#  {'Customer_ID': '45',
#   'Customer_Name': 'Frank Martinez',
#   'Age': '38',
#   'Gender': 'Male',
#   'Purchase_Amount': '313.45',
#   'Purchase_Date': '2024-01-14'},
#  {'Customer_ID': '46',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '47',
#   'Gender': 'Female',
#   'Purchase_Amount': '349.88',
#   'Purchase_Date': '2023-07-05'},
#  {'Customer_ID': '47',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '23',
#   'Gender': 'Female',
#   'Purchase_Amount': '933.63',
#   'Purchase_Date': '2024-03-18'},
#  {'Customer_ID': '48',
#   'Customer_Name': 'Alice Smith',
#   'Age': '23',
#   'Gender': 'Female',
#   'Purchase_Amount': '762.86',
#   'Purchase_Date': '2024-03-04'},
#  {'Customer_ID': '49',
#   'Customer_Name': 'Alice Brown',
#   'Age': '29',
#   'Gender': 'Female',
#   'Purchase_Amount': '920.49',
#   'Purchase_Date': '2024-04-30'},
#  {'Customer_ID': '50',
#   'Customer_Name': 'Bob Smith',
#   'Age': '38',
#   'Gender': 'Female',
#   'Purchase_Amount': '104.47',
#   'Purchase_Date': '2023-12-31'},
#  {'Customer_ID': '51',
#   'Customer_Name': 'Frank Brown',
#   'Age': '46',
#   'Gender': 'Male',
#   'Purchase_Amount': '621.47',
#   'Purchase_Date': '2023-12-30'},
#  {'Customer_ID': '52',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '281.35',
#   'Purchase_Date': '2023-07-02'},
#  {'Customer_ID': '53',
#   'Customer_Name': 'Alice Miller',
#   'Age': '31',
#   'Gender': 'Female',
#   'Purchase_Amount': '396.19',
#   'Purchase_Date': '2023-09-17'},
#  {'Customer_ID': '54',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '39',
#   'Gender': 'Female',
#   'Purchase_Amount': '778.26',
#   'Purchase_Date': '2024-05-08'},
#  {'Customer_ID': '55',
#   'Customer_Name': 'Grace Brown',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '388.92',
#   'Purchase_Date': '2023-12-20'},
#  {'Customer_ID': '56',
#   'Customer_Name': 'Henry Miller',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '85.85',
#   'Purchase_Date': '2024-02-26'},
#  {'Customer_ID': '57',
#   'Customer_Name': 'Charlie Martinez',
#   'Age': '40',
#   'Gender': 'Female',
#   'Purchase_Amount': '268.41',
#   'Purchase_Date': '2023-08-29'},
#  {'Customer_ID': '58',
#   'Customer_Name': 'Alice Jones',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '397.89',
#   'Purchase_Date': '2023-10-04'},
#  {'Customer_ID': '59',
#   'Customer_Name': 'Grace Martinez',
#   'Age': '37',
#   'Gender': 'Male',
#   'Purchase_Amount': '588.02',
#   'Purchase_Date': '2024-03-13'},
#  {'Customer_ID': '60',
#   'Customer_Name': 'David Davis',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '698.82',
#   'Purchase_Date': '2023-11-21'},
#  {'Customer_ID': '61',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '18',
#   'Gender': 'Male',
#   'Purchase_Amount': '194.19',
#   'Purchase_Date': '2023-12-23'},
#  {'Customer_ID': '62',
#   'Customer_Name': 'Alice Davis',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '376.8',
#   'Purchase_Date': '2024-03-20'},
#  {'Customer_ID': '63',
#   'Customer_Name': 'David Rodriguez',
#   'Age': '48',
#   'Gender': 'Male',
#   'Purchase_Amount': '447.09',
#   'Purchase_Date': '2023-09-05'},
#  {'Customer_ID': '64',
#   'Customer_Name': 'Henry Brown',
#   'Age': '35',
#   'Gender': 'Male',
#   'Purchase_Amount': '823.0',
#   'Purchase_Date': '2023-10-08'},
#  {'Customer_ID': '65',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '32',
#   'Gender': 'Female',
#   'Purchase_Amount': '726.87',
#   'Purchase_Date': '2024-01-06'},
#  {'Customer_ID': '66',
#   'Customer_Name': 'Alice Davis',
#   'Age': '68',
#   'Gender': 'Male',
#   'Purchase_Amount': '377.11',
#   'Purchase_Date': '2024-02-22'},
#  {'Customer_ID': '67',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '60',
#   'Gender': 'Female',
#   'Purchase_Amount': '335.99',
#   'Purchase_Date': '2023-10-03'},
#  {'Customer_ID': '68',
#   'Customer_Name': 'Frank Miller',
#   'Age': '34',
#   'Gender': 'Female',
#   'Purchase_Amount': '873.36',
#   'Purchase_Date': '2024-01-27'},
#  {'Customer_ID': '69',
#   'Customer_Name': 'Bob Martinez',
#   'Age': '50',
#   'Gender': 'Female',
#   'Purchase_Amount': '574.54',
#   'Purchase_Date': '2024-05-09'},
#  {'Customer_ID': '70',
#   'Customer_Name': 'Bob Williams',
#   'Age': '48',
#   'Gender': 'Female',
#   'Purchase_Amount': '711.75',
#   'Purchase_Date': '2024-04-11'},
#  {'Customer_ID': '71',
#   'Customer_Name': 'Henry Williams',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '323.66',
#   'Purchase_Date': '2023-08-20'},
#  {'Customer_ID': '72',
#   'Customer_Name': 'Frank Miller',
#   'Age': '66',
#   'Gender': 'Female',
#   'Purchase_Amount': '932.36',
#   'Purchase_Date': '2024-02-19'},
#  {'Customer_ID': '73',
#   'Customer_Name': 'Jack Rodriguez',
#   'Age': '70',
#   'Gender': 'Male',
#   'Purchase_Amount': '114.88',
#   'Purchase_Date': '2023-06-21'},
#  {'Customer_ID': '74',
#   'Customer_Name': 'Emma Johnson',
#   'Age': '21',
#   'Gender': 'Female',
#   'Purchase_Amount': '529.71',
#   'Purchase_Date': '2023-08-11'},
#  {'Customer_ID': '75',
#   'Customer_Name': 'Ivy Williams',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '779.41',
#   'Purchase_Date': '2023-12-04'},
#  {'Customer_ID': '76',
#   'Customer_Name': 'David Rodriguez',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '212.29',
#   'Purchase_Date': '2024-03-16'},
#  {'Customer_ID': '77',
#   'Customer_Name': 'Frank Rodriguez',
#   'Age': '69',
#   'Gender': 'Female',
#   'Purchase_Amount': '586.67',
#   'Purchase_Date': '2024-04-25'},
#  {'Customer_ID': '78',
#   'Customer_Name': 'Charlie Miller',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '510.7',
#   'Purchase_Date': '2024-02-04'},
#  {'Customer_ID': '79',
#   'Customer_Name': 'Bob Brown',
#   'Age': '27',
#   'Gender': 'Female',
#   'Purchase_Amount': '761.49',
#   'Purchase_Date': '2024-05-20'},
#  {'Customer_ID': '80',
#   'Customer_Name': 'Charlie Jones',
#   'Age': '38',
#   'Gender': 'Female',
#   'Purchase_Amount': '282.35',
#   'Purchase_Date': '2024-04-14'},
#  {'Customer_ID': '81',
#   'Customer_Name': 'Bob Rodriguez',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '439.0',
#   'Purchase_Date': '2024-03-09'},
#  {'Customer_ID': '82',
#   'Customer_Name': 'Jack Miller',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '293.95',
#   'Purchase_Date': '2023-10-25'},
#  {'Customer_ID': '83',
#   'Customer_Name': 'Alice Martinez',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '185.83',
#   'Purchase_Date': '2024-02-20'},
#  {'Customer_ID': '84',
#   'Customer_Name': 'David Jones',
#   'Age': '25',
#   'Gender': 'Male',
#   'Purchase_Amount': '578.27',
#   'Purchase_Date': '2023-07-14'},
#  {'Customer_ID': '85',
#   'Customer_Name': 'Emma Jones',
#   'Age': '69',
#   'Gender': 'Female',
#   'Purchase_Amount': '480.21',
#   'Purchase_Date': '2024-05-17'},
#  {'Customer_ID': '86',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '34',
#   'Gender': 'Male',
#   'Purchase_Amount': '906.17',
#   'Purchase_Date': '2024-01-27'},
#  {'Customer_ID': '87',
#   'Customer_Name': 'Henry Johnson',
#   'Age': '27',
#   'Gender': 'Female',
#   'Purchase_Amount': '586.82',
#   'Purchase_Date': '2023-08-02'},
#  {'Customer_ID': '88',
#   'Customer_Name': 'Jack Rodriguez',
#   'Age': '30',
#   'Gender': 'Male',
#   'Purchase_Amount': '840.43',
#   'Purchase_Date': '2023-07-27'},
#  {'Customer_ID': '89',
#   'Customer_Name': 'Alice Smith',
#   'Age': '19',
#   'Gender': 'Female',
#   'Purchase_Amount': '602.63',
#   'Purchase_Date': '2024-04-01'},
#  {'Customer_ID': '90',
#   'Customer_Name': 'Ivy Davis',
#   'Age': '55',
#   'Gender': 'Female',
#   'Purchase_Amount': '405.7',
#   'Purchase_Date': '2024-04-10'},
#  {'Customer_ID': '91',
#   'Customer_Name': 'Alice Jones',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '960.03',
#   'Purchase_Date': '2023-12-26'},
#  {'Customer_ID': '92',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '19',
#   'Gender': 'Female',
#   'Purchase_Amount': '676.08',
#   'Purchase_Date': '2023-12-18'},
#  {'Customer_ID': '93',
#   'Customer_Name': 'Bob Rodriguez',
#   'Age': '26',
#   'Gender': 'Male',
#   'Purchase_Amount': '891.46',
#   'Purchase_Date': '2024-01-22'},
#  {'Customer_ID': '94',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '489.22',
#   'Purchase_Date': '2024-05-03'},
#  {'Customer_ID': '95',
#   'Customer_Name': 'Jack Brown',
#   'Age': '51',
#   'Gender': 'Female',
#   'Purchase_Amount': '649.88',
#   'Purchase_Date': '2024-05-13'},
#  {'Customer_ID': '96',
#   'Customer_Name': 'Grace Miller',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '461.16',
#   'Purchase_Date': '2023-12-03'},
#  {'Customer_ID': '97',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '21',
#   'Gender': 'Male',
#   'Purchase_Amount': '465.45',
#   'Purchase_Date': '2023-09-06'},
#  {'Customer_ID': '98',
#   'Customer_Name': 'Grace Davis',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '796.25',
#   'Purchase_Date': '2023-07-07'},
#  {'Customer_ID': '84',
#   'Customer_Name': 'David Jones',
#   'Age': '25',
#   'Gender': 'Male',
#   'Purchase_Amount': '578.27',
#   'Purchase_Date': '2023-07-14'},
#  {'Customer_ID': '85',
#   'Customer_Name': 'Emma Jones',
#   'Age': '69',
#   'Gender': 'Female',
#   'Purchase_Amount': '480.21',
#   'Purchase_Date': '2024-05-17'},
#  {'Customer_ID': '86',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '34',
#   'Gender': 'Male',
#   'Purchase_Amount': '906.17',
#   'Purchase_Date': '2024-01-27'},
#  {'Customer_ID': '87',
#   'Customer_Name': 'Henry Johnson',
#   'Age': '27',
#   'Gender': 'Female',
#   'Purchase_Amount': '586.82',
#   'Purchase_Date': '2023-08-02'},
#  {'Customer_ID': '88',
#   'Customer_Name': 'Jack Rodriguez',
#   'Age': '30',
#   'Gender': 'Male',
#   'Purchase_Amount': '840.43',
#   'Purchase_Date': '2023-07-27'},
#  {'Customer_ID': '89',
#   'Customer_Name': 'Alice Smith',
#   'Age': '19',
#   'Gender': 'Female',
#   'Purchase_Amount': '602.63',
#   'Purchase_Date': '2024-04-01'},
#  {'Customer_ID': '90',
#   'Customer_Name': 'Ivy Davis',
#   'Age': '55',
#   'Gender': 'Female',
#   'Purchase_Amount': '405.7',
#   'Purchase_Date': '2024-04-10'},
#  {'Customer_ID': '91',
#   'Customer_Name': 'Alice Jones',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '960.03',
#   'Purchase_Date': '2023-12-26'},
#  {'Customer_ID': '99',
#   'Customer_Name': 'Alice Johnson',
#   'Age': '',
#   'Gender': 'Female',
#   'Purchase_Amount': '781.83',
#   'Purchase_Date': '2023-06-04'},
#  {'Customer_ID': '100',
#   'Customer_Name': 'Jack Garcia',
#   'Age': '',
#   'Gender': 'Female',
#   'Purchase_Amount': '269.64',
#   'Purchase_Date': '2024-03-08'}]

# %%
# 2: How do you remove duplciate rows based on Customer ID  
data_unique = []
customer_ids_seen = set()
for row in data:
    if row["Customer_ID"] not in customer_ids_seen:
        data_unique.append(row)
        customer_ids_seen.add(row["Customer_ID"])
    else:
        print(f'duplciate customer id {row["Customer_ID"]}')
# Out:
# duplciate customer id 84
# duplciate customer id 85
# duplciate customer id 86
# duplciate customer id 87
# duplciate customer id 88
# duplciate customer id 89
# duplciate customer id 90
# duplciate customer id 91

# %%
data_unique
# Out:
# [{'Customer_ID': '1',
#   'Customer_Name': 'Henry Jones',
#   'Age': '32',
#   'Gender': 'Male',
#   'Purchase_Amount': '1080000.66',
#   'Purchase_Date': '2023-08-15'},
#  {'Customer_ID': '2',
#   'Customer_Name': 'Emma Rodriguez',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '62.4',
#   'Purchase_Date': '2024-04-16'},
#  {'Customer_ID': '3',
#   'Customer_Name': 'Frank Martinez',
#   'Age': '20',
#   'Gender': 'Female',
#   'Purchase_Amount': '443.47',
#   'Purchase_Date': '2024-05-16'},
#  {'Customer_ID': '4',
#   'Customer_Name': 'Alice Rodriguez',
#   'Age': '62',
#   'Gender': 'Female',
#   'Purchase_Amount': '729.69',
#   'Purchase_Date': '2024-01-05'},
#  {'Customer_ID': '5',
#   'Customer_Name': 'Frank Miller',
#   'Age': '33',
#   'Gender': 'Female',
#   'Purchase_Amount': '651.2',
#   'Purchase_Date': '2024-05-23'},
#  {'Customer_ID': '6',
#   'Customer_Name': 'Emma Garcia',
#   'Age': '22',
#   'Gender': 'Female',
#   'Purchase_Amount': '477.56',
#   'Purchase_Date': '2023-09-02'},
#  {'Customer_ID': '7',
#   'Customer_Name': 'Grace Jones',
#   'Age': '53',
#   'Gender': 'Female',
#   'Purchase_Amount': '29.72',
#   'Purchase_Date': '2023-10-01'},
#  {'Customer_ID': '8',
#   'Customer_Name': 'Henry Smith',
#   'Age': '41',
#   'Gender': 'Male',
#   'Purchase_Amount': '291.28',
#   'Purchase_Date': '2024-02-01'},
#  {'Customer_ID': '9',
#   'Customer_Name': 'Emma Jones',
#   'Age': '50',
#   'Gender': 'Female',
#   'Purchase_Amount': '575.69',
#   'Purchase_Date': '2023-12-11'},
#  {'Customer_ID': '10',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '44',
#   'Gender': 'Female',
#   'Purchase_Amount': '30.96',
#   'Purchase_Date': '2024-05-11'},
#  {'Customer_ID': '11',
#   'Customer_Name': 'Grace Miller',
#   'Age': '29',
#   'Gender': 'Male',
#   'Purchase_Amount': '321.42',
#   'Purchase_Date': '2023-10-25'},
#  {'Customer_ID': '12',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '68',
#   'Gender': 'Male',
#   'Purchase_Amount': '470.45',
#   'Purchase_Date': '2023-06-05'},
#  {'Customer_ID': '13',
#   'Customer_Name': 'Charlie Jones',
#   'Age': '24',
#   'Gender': 'Female',
#   'Purchase_Amount': '330.87',
#   'Purchase_Date': '2023-11-11'},
#  {'Customer_ID': '14',
#   'Customer_Name': 'Frank Rodriguez',
#   'Age': '51',
#   'Gender': 'Female',
#   'Purchase_Amount': '483.61',
#   'Purchase_Date': '2024-05-06'},
#  {'Customer_ID': '15',
#   'Customer_Name': 'Alice Jones',
#   'Age': '53',
#   'Gender': 'Male',
#   'Purchase_Amount': '647.13',
#   'Purchase_Date': '2023-12-07'},
#  {'Customer_ID': '16',
#   'Customer_Name': 'Grace Miller',
#   'Age': '36',
#   'Gender': 'Female',
#   'Purchase_Amount': '691.85',
#   'Purchase_Date': '2023-09-25'},
#  {'Customer_ID': '17',
#   'Customer_Name': 'Charlie Miller',
#   'Age': '27',
#   'Gender': 'Male',
#   'Purchase_Amount': '840.67',
#   'Purchase_Date': '2023-07-09'},
#  {'Customer_ID': '18',
#   'Customer_Name': 'Jack Martinez',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '831.8',
#   'Purchase_Date': '2023-11-07'},
#  {'Customer_ID': '19',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '399.76',
#   'Purchase_Date': '2024-02-04'},
#  {'Customer_ID': '20',
#   'Customer_Name': 'Grace Miller',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '917.93',
#   'Purchase_Date': '2023-12-24'},
#  {'Customer_ID': '21',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '21',
#   'Gender': 'Female',
#   'Purchase_Amount': '389.69',
#   'Purchase_Date': '2023-07-19'},
#  {'Customer_ID': '22',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '34',
#   'Gender': 'Male',
#   'Purchase_Amount': '697.0',
#   'Purchase_Date': '2023-07-15'},
#  {'Customer_ID': '23',
#   'Customer_Name': 'Jack Miller',
#   'Age': '55',
#   'Gender': 'Male',
#   'Purchase_Amount': '838.01',
#   'Purchase_Date': '2023-10-22'},
#  {'Customer_ID': '24',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '620.28',
#   'Purchase_Date': '2024-01-19'},
#  {'Customer_ID': '25',
#   'Customer_Name': 'David Johnson',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '964.04',
#   'Purchase_Date': '2023-12-30'},
#  {'Customer_ID': '26',
#   'Customer_Name': 'David Smith',
#   'Age': '36',
#   'Gender': 'Female',
#   'Purchase_Amount': '231.88',
#   'Purchase_Date': '2024-05-27'},
#  {'Customer_ID': '27',
#   'Customer_Name': 'Ivy Martinez',
#   'Age': '22',
#   'Gender': 'Female',
#   'Purchase_Amount': '115.68',
#   'Purchase_Date': '2023-08-24'},
#  {'Customer_ID': '28',
#   'Customer_Name': 'Henry Martinez',
#   'Age': '62',
#   'Gender': 'Male',
#   'Purchase_Amount': '735.66',
#   'Purchase_Date': '2023-12-07'},
#  {'Customer_ID': '29',
#   'Customer_Name': 'Charlie Garcia',
#   'Age': '42',
#   'Gender': 'Female',
#   'Purchase_Amount': '696.19',
#   'Purchase_Date': '2023-07-26'},
#  {'Customer_ID': '30',
#   'Customer_Name': 'Grace Davis',
#   'Age': '30',
#   'Gender': 'Female',
#   'Purchase_Amount': '566.13',
#   'Purchase_Date': '2023-07-18'},
#  {'Customer_ID': '31',
#   'Customer_Name': 'Grace Smith',
#   'Age': '19',
#   'Gender': 'Male',
#   'Purchase_Amount': '567.3',
#   'Purchase_Date': '2024-04-13'},
#  {'Customer_ID': '32',
#   'Customer_Name': 'Emma Jones',
#   'Age': '58',
#   'Gender': 'Male',
#   'Purchase_Amount': '299.82',
#   'Purchase_Date': '2024-03-21'},
#  {'Customer_ID': '33',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '43',
#   'Gender': 'Male',
#   'Purchase_Amount': '366.42',
#   'Purchase_Date': '2023-07-30'},
#  {'Customer_ID': '34',
#   'Customer_Name': 'Alice Garcia',
#   'Age': '54',
#   'Gender': 'Male',
#   'Purchase_Amount': '874.08',
#   'Purchase_Date': '2024-04-17'},
#  {'Customer_ID': '35',
#   'Customer_Name': 'Grace Williams',
#   'Age': '58',
#   'Gender': 'Male',
#   'Purchase_Amount': '139.01',
#   'Purchase_Date': '2024-04-23'},
#  {'Customer_ID': '36',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '637.05',
#   'Purchase_Date': '2023-08-06'},
#  {'Customer_ID': '37',
#   'Customer_Name': 'Ivy Miller',
#   'Age': '37',
#   'Gender': 'Male',
#   'Purchase_Amount': '787.06',
#   'Purchase_Date': '2024-05-04'},
#  {'Customer_ID': '38',
#   'Customer_Name': 'Charlie Rodriguez',
#   'Age': '52',
#   'Gender': 'Female',
#   'Purchase_Amount': '853.47',
#   'Purchase_Date': '2023-11-26'},
#  {'Customer_ID': '39',
#   'Customer_Name': 'Grace Garcia',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '901.82',
#   'Purchase_Date': '2023-12-09'},
#  {'Customer_ID': '40',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '61',
#   'Gender': 'Male',
#   'Purchase_Amount': '180.92',
#   'Purchase_Date': '2023-10-02'},
#  {'Customer_ID': '41',
#   'Customer_Name': 'Alice Jones',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '373.03',
#   'Purchase_Date': '2024-03-16'},
#  {'Customer_ID': '42',
#   'Customer_Name': 'Charlie Smith',
#   'Age': '66',
#   'Gender': 'Male',
#   'Purchase_Amount': '392.27',
#   'Purchase_Date': '2023-11-03'},
#  {'Customer_ID': '43',
#   'Customer_Name': 'Bob Williams',
#   'Age': '35',
#   'Gender': 'Female',
#   'Purchase_Amount': '319.58',
#   'Purchase_Date': '2024-03-29'},
#  {'Customer_ID': '44',
#   'Customer_Name': 'Frank Garcia',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '917.63',
#   'Purchase_Date': '2023-07-26'},
#  {'Customer_ID': '45',
#   'Customer_Name': 'Frank Martinez',
#   'Age': '38',
#   'Gender': 'Male',
#   'Purchase_Amount': '313.45',
#   'Purchase_Date': '2024-01-14'},
#  {'Customer_ID': '46',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '47',
#   'Gender': 'Female',
#   'Purchase_Amount': '349.88',
#   'Purchase_Date': '2023-07-05'},
#  {'Customer_ID': '47',
#   'Customer_Name': 'Grace Rodriguez',
#   'Age': '23',
#   'Gender': 'Female',
#   'Purchase_Amount': '933.63',
#   'Purchase_Date': '2024-03-18'},
#  {'Customer_ID': '48',
#   'Customer_Name': 'Alice Smith',
#   'Age': '23',
#   'Gender': 'Female',
#   'Purchase_Amount': '762.86',
#   'Purchase_Date': '2024-03-04'},
#  {'Customer_ID': '49',
#   'Customer_Name': 'Alice Brown',
#   'Age': '29',
#   'Gender': 'Female',
#   'Purchase_Amount': '920.49',
#   'Purchase_Date': '2024-04-30'},
#  {'Customer_ID': '50',
#   'Customer_Name': 'Bob Smith',
#   'Age': '38',
#   'Gender': 'Female',
#   'Purchase_Amount': '104.47',
#   'Purchase_Date': '2023-12-31'},
#  {'Customer_ID': '51',
#   'Customer_Name': 'Frank Brown',
#   'Age': '46',
#   'Gender': 'Male',
#   'Purchase_Amount': '621.47',
#   'Purchase_Date': '2023-12-30'},
#  {'Customer_ID': '52',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '281.35',
#   'Purchase_Date': '2023-07-02'},
#  {'Customer_ID': '53',
#   'Customer_Name': 'Alice Miller',
#   'Age': '31',
#   'Gender': 'Female',
#   'Purchase_Amount': '396.19',
#   'Purchase_Date': '2023-09-17'},
#  {'Customer_ID': '54',
#   'Customer_Name': 'Emma Martinez',
#   'Age': '39',
#   'Gender': 'Female',
#   'Purchase_Amount': '778.26',
#   'Purchase_Date': '2024-05-08'},
#  {'Customer_ID': '55',
#   'Customer_Name': 'Grace Brown',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '388.92',
#   'Purchase_Date': '2023-12-20'},
#  {'Customer_ID': '56',
#   'Customer_Name': 'Henry Miller',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '85.85',
#   'Purchase_Date': '2024-02-26'},
#  {'Customer_ID': '57',
#   'Customer_Name': 'Charlie Martinez',
#   'Age': '40',
#   'Gender': 'Female',
#   'Purchase_Amount': '268.41',
#   'Purchase_Date': '2023-08-29'},
#  {'Customer_ID': '58',
#   'Customer_Name': 'Alice Jones',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '397.89',
#   'Purchase_Date': '2023-10-04'},
#  {'Customer_ID': '59',
#   'Customer_Name': 'Grace Martinez',
#   'Age': '37',
#   'Gender': 'Male',
#   'Purchase_Amount': '588.02',
#   'Purchase_Date': '2024-03-13'},
#  {'Customer_ID': '60',
#   'Customer_Name': 'David Davis',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '698.82',
#   'Purchase_Date': '2023-11-21'},
#  {'Customer_ID': '61',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '18',
#   'Gender': 'Male',
#   'Purchase_Amount': '194.19',
#   'Purchase_Date': '2023-12-23'},
#  {'Customer_ID': '62',
#   'Customer_Name': 'Alice Davis',
#   'Age': '50',
#   'Gender': 'Male',
#   'Purchase_Amount': '376.8',
#   'Purchase_Date': '2024-03-20'},
#  {'Customer_ID': '63',
#   'Customer_Name': 'David Rodriguez',
#   'Age': '48',
#   'Gender': 'Male',
#   'Purchase_Amount': '447.09',
#   'Purchase_Date': '2023-09-05'},
#  {'Customer_ID': '64',
#   'Customer_Name': 'Henry Brown',
#   'Age': '35',
#   'Gender': 'Male',
#   'Purchase_Amount': '823.0',
#   'Purchase_Date': '2023-10-08'},
#  {'Customer_ID': '65',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '32',
#   'Gender': 'Female',
#   'Purchase_Amount': '726.87',
#   'Purchase_Date': '2024-01-06'},
#  {'Customer_ID': '66',
#   'Customer_Name': 'Alice Davis',
#   'Age': '68',
#   'Gender': 'Male',
#   'Purchase_Amount': '377.11',
#   'Purchase_Date': '2024-02-22'},
#  {'Customer_ID': '67',
#   'Customer_Name': 'Frank Johnson',
#   'Age': '60',
#   'Gender': 'Female',
#   'Purchase_Amount': '335.99',
#   'Purchase_Date': '2023-10-03'},
#  {'Customer_ID': '68',
#   'Customer_Name': 'Frank Miller',
#   'Age': '34',
#   'Gender': 'Female',
#   'Purchase_Amount': '873.36',
#   'Purchase_Date': '2024-01-27'},
#  {'Customer_ID': '69',
#   'Customer_Name': 'Bob Martinez',
#   'Age': '50',
#   'Gender': 'Female',
#   'Purchase_Amount': '574.54',
#   'Purchase_Date': '2024-05-09'},
#  {'Customer_ID': '70',
#   'Customer_Name': 'Bob Williams',
#   'Age': '48',
#   'Gender': 'Female',
#   'Purchase_Amount': '711.75',
#   'Purchase_Date': '2024-04-11'},
#  {'Customer_ID': '71',
#   'Customer_Name': 'Henry Williams',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '323.66',
#   'Purchase_Date': '2023-08-20'},
#  {'Customer_ID': '72',
#   'Customer_Name': 'Frank Miller',
#   'Age': '66',
#   'Gender': 'Female',
#   'Purchase_Amount': '932.36',
#   'Purchase_Date': '2024-02-19'},
#  {'Customer_ID': '73',
#   'Customer_Name': 'Jack Rodriguez',
#   'Age': '70',
#   'Gender': 'Male',
#   'Purchase_Amount': '114.88',
#   'Purchase_Date': '2023-06-21'},
#  {'Customer_ID': '74',
#   'Customer_Name': 'Emma Johnson',
#   'Age': '21',
#   'Gender': 'Female',
#   'Purchase_Amount': '529.71',
#   'Purchase_Date': '2023-08-11'},
#  {'Customer_ID': '75',
#   'Customer_Name': 'Ivy Williams',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '779.41',
#   'Purchase_Date': '2023-12-04'},
#  {'Customer_ID': '76',
#   'Customer_Name': 'David Rodriguez',
#   'Age': '23',
#   'Gender': 'Male',
#   'Purchase_Amount': '212.29',
#   'Purchase_Date': '2024-03-16'},
#  {'Customer_ID': '77',
#   'Customer_Name': 'Frank Rodriguez',
#   'Age': '69',
#   'Gender': 'Female',
#   'Purchase_Amount': '586.67',
#   'Purchase_Date': '2024-04-25'},
#  {'Customer_ID': '78',
#   'Customer_Name': 'Charlie Miller',
#   'Age': '24',
#   'Gender': 'Male',
#   'Purchase_Amount': '510.7',
#   'Purchase_Date': '2024-02-04'},
#  {'Customer_ID': '79',
#   'Customer_Name': 'Bob Brown',
#   'Age': '27',
#   'Gender': 'Female',
#   'Purchase_Amount': '761.49',
#   'Purchase_Date': '2024-05-20'},
#  {'Customer_ID': '80',
#   'Customer_Name': 'Charlie Jones',
#   'Age': '38',
#   'Gender': 'Female',
#   'Purchase_Amount': '282.35',
#   'Purchase_Date': '2024-04-14'},
#  {'Customer_ID': '81',
#   'Customer_Name': 'Bob Rodriguez',
#   'Age': '54',
#   'Gender': 'Female',
#   'Purchase_Amount': '439.0',
#   'Purchase_Date': '2024-03-09'},
#  {'Customer_ID': '82',
#   'Customer_Name': 'Jack Miller',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '293.95',
#   'Purchase_Date': '2023-10-25'},
#  {'Customer_ID': '83',
#   'Customer_Name': 'Alice Martinez',
#   'Age': '41',
#   'Gender': 'Female',
#   'Purchase_Amount': '185.83',
#   'Purchase_Date': '2024-02-20'},
#  {'Customer_ID': '84',
#   'Customer_Name': 'David Jones',
#   'Age': '25',
#   'Gender': 'Male',
#   'Purchase_Amount': '578.27',
#   'Purchase_Date': '2023-07-14'},
#  {'Customer_ID': '85',
#   'Customer_Name': 'Emma Jones',
#   'Age': '69',
#   'Gender': 'Female',
#   'Purchase_Amount': '480.21',
#   'Purchase_Date': '2024-05-17'},
#  {'Customer_ID': '86',
#   'Customer_Name': 'Bob Garcia',
#   'Age': '34',
#   'Gender': 'Male',
#   'Purchase_Amount': '906.17',
#   'Purchase_Date': '2024-01-27'},
#  {'Customer_ID': '87',
#   'Customer_Name': 'Henry Johnson',
#   'Age': '27',
#   'Gender': 'Female',
#   'Purchase_Amount': '586.82',
#   'Purchase_Date': '2023-08-02'},
#  {'Customer_ID': '88',
#   'Customer_Name': 'Jack Rodriguez',
#   'Age': '30',
#   'Gender': 'Male',
#   'Purchase_Amount': '840.43',
#   'Purchase_Date': '2023-07-27'},
#  {'Customer_ID': '89',
#   'Customer_Name': 'Alice Smith',
#   'Age': '19',
#   'Gender': 'Female',
#   'Purchase_Amount': '602.63',
#   'Purchase_Date': '2024-04-01'},
#  {'Customer_ID': '90',
#   'Customer_Name': 'Ivy Davis',
#   'Age': '55',
#   'Gender': 'Female',
#   'Purchase_Amount': '405.7',
#   'Purchase_Date': '2024-04-10'},
#  {'Customer_ID': '91',
#   'Customer_Name': 'Alice Jones',
#   'Age': '64',
#   'Gender': 'Female',
#   'Purchase_Amount': '960.03',
#   'Purchase_Date': '2023-12-26'},
#  {'Customer_ID': '92',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '19',
#   'Gender': 'Female',
#   'Purchase_Amount': '676.08',
#   'Purchase_Date': '2023-12-18'},
#  {'Customer_ID': '93',
#   'Customer_Name': 'Bob Rodriguez',
#   'Age': '26',
#   'Gender': 'Male',
#   'Purchase_Amount': '891.46',
#   'Purchase_Date': '2024-01-22'},
#  {'Customer_ID': '94',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '56',
#   'Gender': 'Male',
#   'Purchase_Amount': '489.22',
#   'Purchase_Date': '2024-05-03'},
#  {'Customer_ID': '95',
#   'Customer_Name': 'Jack Brown',
#   'Age': '51',
#   'Gender': 'Female',
#   'Purchase_Amount': '649.88',
#   'Purchase_Date': '2024-05-13'},
#  {'Customer_ID': '96',
#   'Customer_Name': 'Grace Miller',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '461.16',
#   'Purchase_Date': '2023-12-03'},
#  {'Customer_ID': '97',
#   'Customer_Name': 'Ivy Brown',
#   'Age': '21',
#   'Gender': 'Male',
#   'Purchase_Amount': '465.45',
#   'Purchase_Date': '2023-09-06'},
#  {'Customer_ID': '98',
#   'Customer_Name': 'Grace Davis',
#   'Age': '42',
#   'Gender': 'Male',
#   'Purchase_Amount': '796.25',
#   'Purchase_Date': '2023-07-07'},
#  {'Customer_ID': '99',
#   'Customer_Name': 'Alice Johnson',
#   'Age': '',
#   'Gender': 'Female',
#   'Purchase_Amount': '781.83',
#   'Purchase_Date': '2023-06-04'},
#  {'Customer_ID': '100',
#   'Customer_Name': 'Jack Garcia',
#   'Age': '',
#   'Gender': 'Female',
#   'Purchase_Amount': '269.64',
#   'Purchase_Date': '2024-03-08'}]

# %%
# 3: How to handle missing values by replacing them with 0 

for row in data_unique:
    if not row["Age"]:
        print(f'Customer {row["Customer_Name"]} does not have Age value')
        row["Age"] = 0 
    if not row["Purchase_Amount"]:
        row["Purchase_Amount"] = 0.0
# Out:
# Customer Alice Johnson does not have Age vale
# Customer Jack Garcia does not have Age vale

# %%
# 4: How to remove outliers such as Age > 100 or purchase amount > 1000

# instead of writing what to remove, we keep only what we need (so keep the rows if the age is less than or equal to 100 and purchase amount is less than or equal to 1000)

data_cleaned = [
    row
    for row in data_unique
    if int(row["Age"]) <= 100 and float(row["Purchase_Amount"]) <= 1000
]

# %%
# 5: How to convert the Gender column to a binary format (0 for female, 1 for male) - one hot encoding 

for row in data_cleaned:
    if row["Gender"] == "Female":
        row["Gender"] = 0
    elif row["Gender"] == "Male":
        row["Gender"] = 1

print(data_cleaned[:5])
# Out:
# [{'Customer_ID': '2', 'Customer_Name': 'Emma Rodriguez', 'Age': '24', 'Gender': 1, 'Purchase_Amount': '62.4', 'Purchase_Date': '2024-04-16'}, {'Customer_ID': '3', 'Customer_Name': 'Frank Martinez', 'Age': '20', 'Gender': 0, 'Purchase_Amount': '443.47', 'Purchase_Date': '2024-05-16'}, {'Customer_ID': '4', 'Customer_Name': 'Alice Rodriguez', 'Age': '62', 'Gender': 0, 'Purchase_Amount': '729.69', 'Purchase_Date': '2024-01-05'}, {'Customer_ID': '5', 'Customer_Name': 'Frank Miller', 'Age': '33', 'Gender': 0, 'Purchase_Amount': '651.2', 'Purchase_Date': '2024-05-23'}, {'Customer_ID': '6', 'Customer_Name': 'Emma Garcia', 'Age': '22', 'Gender': 0, 'Purchase_Amount': '477.56', 'Purchase_Date': '2023-09-02'}]

# %%
# 6: split customer_name into separate first and last name columns 

for row in data_cleaned:
    first_name, last_name = row["Customer_Name"].split(" ", 1)
    row["First_Name"] = first_name
    row["Last_Name"] = last_name
    del row["Customer_Name"]

print(data_cleaned[5:])
# Out:
# [{'Customer_ID': '7', 'Age': '53', 'Gender': 0, 'Purchase_Amount': '29.72', 'Purchase_Date': '2023-10-01', 'First_Name': 'Grace', 'Last_Name': 'Jones'}, {'Customer_ID': '8', 'Age': '41', 'Gender': 1, 'Purchase_Amount': '291.28', 'Purchase_Date': '2024-02-01', 'First_Name': 'Henry', 'Last_Name': 'Smith'}, {'Customer_ID': '9', 'Age': '50', 'Gender': 0, 'Purchase_Amount': '575.69', 'Purchase_Date': '2023-12-11', 'First_Name': 'Emma', 'Last_Name': 'Jones'}, {'Customer_ID': '10', 'Age': '44', 'Gender': 0, 'Purchase_Amount': '30.96', 'Purchase_Date': '2024-05-11', 'First_Name': 'Ivy', 'Last_Name': 'Martinez'}, {'Customer_ID': '11', 'Age': '29', 'Gender': 1, 'Purchase_Amount': '321.42', 'Purchase_Date': '2023-10-25', 'First_Name': 'Grace', 'Last_Name': 'Miller'}, {'Customer_ID': '12', 'Age': '68', 'Gender': 1, 'Purchase_Amount': '470.45', 'Purchase_Date': '2023-06-05', 'First_Name': 'Ivy', 'Last_Name': 'Martinez'}, {'Customer_ID': '13', 'Age': '24', 'Gender': 0, 'Purchase_Amount': '330.87', 'Purchase_Date': '2023-11-11', 'First_Name': 'Charlie', 'Last_Name': 'Jones'}, {'Customer_ID': '14', 'Age': '51', 'Gender': 0, 'Purchase_Amount': '483.61', 'Purchase_Date': '2024-05-06', 'First_Name': 'Frank', 'Last_Name': 'Rodriguez'}, {'Customer_ID': '15', 'Age': '53', 'Gender': 1, 'Purchase_Amount': '647.13', 'Purchase_Date': '2023-12-07', 'First_Name': 'Alice', 'Last_Name': 'Jones'}, {'Customer_ID': '16', 'Age': '36', 'Gender': 0, 'Purchase_Amount': '691.85', 'Purchase_Date': '2023-09-25', 'First_Name': 'Grace', 'Last_Name': 'Miller'}, {'Customer_ID': '17', 'Age': '27', 'Gender': 1, 'Purchase_Amount': '840.67', 'Purchase_Date': '2023-07-09', 'First_Name': 'Charlie', 'Last_Name': 'Miller'}, {'Customer_ID': '18', 'Age': '64', 'Gender': 0, 'Purchase_Amount': '831.8', 'Purchase_Date': '2023-11-07', 'First_Name': 'Jack', 'Last_Name': 'Martinez'}, {'Customer_ID': '19', 'Age': '64', 'Gender': 0, 'Purchase_Amount': '399.76', 'Purchase_Date': '2024-02-04', 'First_Name': 'Emma', 'Last_Name': 'Martinez'}, {'Customer_ID': '20', 'Age': '56', 'Gender': 1, 'Purchase_Amount': '917.93', 'Purchase_Date': '2023-12-24', 'First_Name': 'Grace', 'Last_Name': 'Miller'}, {'Customer_ID': '21', 'Age': '21', 'Gender': 0, 'Purchase_Amount': '389.69', 'Purchase_Date': '2023-07-19', 'First_Name': 'Grace', 'Last_Name': 'Rodriguez'}, {'Customer_ID': '22', 'Age': '34', 'Gender': 1, 'Purchase_Amount': '697.0', 'Purchase_Date': '2023-07-15', 'First_Name': 'Ivy', 'Last_Name': 'Brown'}, {'Customer_ID': '23', 'Age': '55', 'Gender': 1, 'Purchase_Amount': '838.01', 'Purchase_Date': '2023-10-22', 'First_Name': 'Jack', 'Last_Name': 'Miller'}, {'Customer_ID': '24', 'Age': '42', 'Gender': 1, 'Purchase_Amount': '620.28', 'Purchase_Date': '2024-01-19', 'First_Name': 'Ivy', 'Last_Name': 'Martinez'}, {'Customer_ID': '25', 'Age': '41', 'Gender': 0, 'Purchase_Amount': '964.04', 'Purchase_Date': '2023-12-30', 'First_Name': 'David', 'Last_Name': 'Johnson'}, {'Customer_ID': '26', 'Age': '36', 'Gender': 0, 'Purchase_Amount': '231.88', 'Purchase_Date': '2024-05-27', 'First_Name': 'David', 'Last_Name': 'Smith'}, {'Customer_ID': '27', 'Age': '22', 'Gender': 0, 'Purchase_Amount': '115.68', 'Purchase_Date': '2023-08-24', 'First_Name': 'Ivy', 'Last_Name': 'Martinez'}, {'Customer_ID': '28', 'Age': '62', 'Gender': 1, 'Purchase_Amount': '735.66', 'Purchase_Date': '2023-12-07', 'First_Name': 'Henry', 'Last_Name': 'Martinez'}, {'Customer_ID': '29', 'Age': '42', 'Gender': 0, 'Purchase_Amount': '696.19', 'Purchase_Date': '2023-07-26', 'First_Name': 'Charlie', 'Last_Name': 'Garcia'}, {'Customer_ID': '30', 'Age': '30', 'Gender': 0, 'Purchase_Amount': '566.13', 'Purchase_Date': '2023-07-18', 'First_Name': 'Grace', 'Last_Name': 'Davis'}, {'Customer_ID': '31', 'Age': '19', 'Gender': 1, 'Purchase_Amount': '567.3', 'Purchase_Date': '2024-04-13', 'First_Name': 'Grace', 'Last_Name': 'Smith'}, {'Customer_ID': '32', 'Age': '58', 'Gender': 1, 'Purchase_Amount': '299.82', 'Purchase_Date': '2024-03-21', 'First_Name': 'Emma' ...

# %%
# 7: calculate the total purchase amount by gender 

total_purchase_by_gender = {}
for row in data_cleaned:
    total_purchase_by_gender[row["Gender"]] += float(row["Purchase_Amount"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 5
#       3 total_purchase_by_gender = {}
#       4 for row in data_cleaned:
# ----> 5     total_purchase_by_gender[row["Gender"]] += float(row["Purchase_Amount"])
#
# KeyError: 1

# %%
total_purchase_by_gender = {}
for row in data_cleaned:
    gender = row["Gender"]
    purchase_amount = float(row["Purchase_Amount"])
    
    if gender not in total_purchase_by_gender:
        total_purchase_by_gender[gender] = 0.0
    
    total_purchase_by_gender[gender] += purchase_amount

total_purchase_by_gender
# Out:
# {1: 24599.890000000003, 0: 28215.780000000002}

# %%
# 8: calculate the average purchase amount by age group 

age_groups = {"18-30": [], "31-40": [], "41-50": [], "51-60": [], "61-70": []}
for row in data_cleaned:
    age = int(row["Age"])
    if age <= 30:
        age_groups["18-30"].append(float(row["Purchase_Amount"]))
    elif age <= 40:
        age_groups["31-40"].append(float(row["Purchase_Amount"]))
    elif age <= 50:
        age_groups["41-50"].append(float(row["Purchase_Amount"]))
    elif age <= 60:
        age_groups["51-60"].append(float(row["Purchase_Amount"]))
    else:
        age_groups["61-70"].append(float(row["Purchase_Amount"]))

    
average_purchase_by_age_group = {
    group: sum(amounts) / len(amounts) for group, amounts in age_groups.items()
}

average_purchase_by_age_group
# Out:
# {'18-30': 567.9048387096775,
#  '31-40': 555.2423529411764,
#  '41-50': 493.946,
#  '51-60': 494.51882352941175,
#  '61-70': 534.6971428571428}

# %%
# Question: How do you print the results for total purchase amount by Gender and average purchase amount by Age group?
print("Total purchase amount by Gender:", total_purchase_by_gender)
print("Average purchase amount by Age group:", average_purchase_by_age_group)
# Out:
# Total purchase amount by Gender: {1: 24599.890000000003, 0: 28215.780000000002}
# Average purchase amount by Age group: {'18-30': 567.9048387096775, '31-40': 555.2423529411764, '41-50': 493.946, '51-60': 494.51882352941175, '61-70': 534.6971428571428}

# %%
# 9: use duckdb for the transformations 

import duckdb

# %%
# connect to DuckDB and load data from a CSV file into a DuckDB table?
# Connect to DuckDB and load data

con = duckdb.connect(database=":memory:", read_only=False)
con.execute(
    "CREATE TABLE data (Customer_ID INTEGER, Customer_Name VARCHAR, Age INTEGER, Gender VARCHAR, Purchase_Amount FLOAT, Purchase_Date DATE)"
)

# %%
# Read data from CSV file into DuckDB table
con.execute("COPY data FROM './data/sample_data.csv' WITH HEADER CSV" )

# %%
# remove duplicate rows based on customer ID in DuckDB?
con.execute("CREATE TABLE data_unique AS SELECT DISTINCT * FROM data")

# %%
#  handle missing values by replacing them with 0 
con.execute(
    "CREATE TABLE data_cleaned_missing AS SELECT \
        Customer_ID, Customer_Name, \
        COALESCE(Age, 0) AS Age , \
        Gender, \
        COALESCE(Purchase_Amount, 0.0) AS Purchase_Amount, \
        Purchase_Date \
        FROM data_unique"
)

# %%
# remove outliers (e.g., age > 100 or purchase amount > 1000) 
con.execute(
    "CREATE TABLE data_cleaned_outliers AS SELECT * FROM data_cleaned_missing \
        WHERE Age <= 100 AND Purchase_Amount <= 1000"
)

# %%
# convert the Gender column to a binary format (0 for Female, 1 for Male) 
con.execute(
    "CREATE TABLE data_cleaned_gender AS SELECT *, \
             CASE WHEN Gender = 'Female' THEN 0 ELSE 1 END AS Gender_Binary \
             FROM data_cleaned_outliers"
)

# %%
# split the Customer_Name column into separate First_Name and Last_Name columns 
con.execute(
    "CREATE TABLE data_cleaned AS SELECT \
             Customer_ID, \
             SPLIT_PART(Customer_Name, ' ', 1) AS First_Name, \
             SPLIT_PART(Customer_Name, ' ', 2) AS Last_Name, \
             Age, Gender_Binary, Purchase_Amount, Purchase_Date \
             FROM data_cleaned_gender"
)

# %%
#  calculate the total purchase amount by Gender
total_purchase_by_gender = con.execute(
    "SELECT Gender_Binary, SUM(Purchase_Amount) AS Total_Purchase_Amount \
                                        FROM data_cleaned_gender \
                                        GROUP BY Gender_Binary"
).fetchall()

# %%
# calculate the average purchase amount by Age group
average_purchase_by_age_group = con.execute(
    "SELECT CASE \
                                             WHEN Age BETWEEN 18 AND 30 THEN '18-30' \
                                             WHEN Age BETWEEN 31 AND 40 THEN '31-40' \
                                             WHEN Age BETWEEN 41 AND 50 THEN '41-50' \
                                             WHEN Age BETWEEN 51 AND 60 THEN '51-60' \
                                             ELSE '61-70' END AS Age_Group, \
                                             AVG(Purchase_Amount) AS Average_Purchase_Amount \
                                             FROM data_cleaned \
                                             GROUP BY Age_Group"
).fetchall()

# %%
# print the results for total purchase amount by Gender and average purchase amount by Age group in DuckDB?
print("====================== Results ======================")
print("Total purchase amount by Gender:")
print(total_purchase_by_gender)
print("Average purchase amount by Age group:")
print(average_purchase_by_age_group)
# Out:
# ====================== Results ======================
# Total purchase amount by Gender:
# [(0, 28215.77996635437), (1, 24599.89005279541)]
# Average purchase amount by Age group:
# [('41-50', 493.946000289917), ('31-40', 555.2423526539523), ('61-70', 533.576874256134), ('18-30', 570.8131050899111), ('51-60', 494.51882250168745)]
